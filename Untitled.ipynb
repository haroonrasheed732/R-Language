# %%
# R is a programming language which is mainly use for data analysis,statistics,and 
# data visualization(scientists,researchers and data analysts use this language)

# %%
#print any statement
print("Hello World")
# Out:
# Hello World

# %%
r
cat("Naam: Haroon\nJob: Teacher\nSubject: R programing")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 r
#       2 cat("Naam: Haroon\nJob: Teacher\nSubject: R programing")
#
# NameError: name 'r' is not defined
