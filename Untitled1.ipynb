# %%
age <- 15

if(age>=40){
    print("you are old")
} else if(age>=30){
    print("you are near to old")
} else if(age>=25){
    print("you are a young boy")
} else{
    print("you are a boy")
}
# Out:
# [1] "you are a boy"
